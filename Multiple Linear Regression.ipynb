# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

weather_data_m = pd.read_csv('WeatherDataM.csv')
weather_data_m
weather_data_m.columns
# Out:
# Index(['Temperature (C)', 'Wind Speed (km/h)', 'Pressure (millibars)',
#        'Humidity'],
#       dtype='object')

# %%
# set features of our model, these are potential inputs
weather_features = ['Temperature (C)','Wind Speed (km/h)','Pressure (millibars)'] 

# set variable X to be our input columns: Temperature,Wind speed, and Pressure
X = weather_data_m[weather_features]

y = weather_data_m.Humidity


# plt.subplot enables us to plot mutliple graphs
# we produce scatter plots for Humidity against each of our input variables

plt.subplot(2,2,1)
plt.scatter(X['Temperature (C)'],y)
plt.subplot(2,2,2)
plt.scatter(X['Wind Speed (km/h)'],y)
plt.subplot(2,2,3)
plt.scatter(X['Pressure (millibars)'],y)

# %%
X= X.drop('Pressure (millibars)', 1)
X
# Out:
# C:\Users\mnank\AppData\Local\Temp\ipykernel_25312\53767805.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X= X.drop('Pressure (millibars)', 1)
#     Temperature (C)  Wind Speed (km/h)
# 0          9.472222            14.1197
# 1          9.355556            14.2646
# 2          9.377778             3.9284
# 3          8.288889            14.1036
# 4          8.755556            11.0446
# 5          9.222222            13.9587
# 6          7.733333            12.3648
# 7          8.772222            14.1519
# 8         10.822222            11.3183
# 9         13.772222            12.5258
# 10        16.016667            17.5651
# 11        17.144444            19.7869
# 12        17.800000            21.9443
# 13        17.333333            20.6885
# 14        18.877778            15.3755
# 15        18.911111            10.4006
# 16        15.388889            14.4095
# 17        15.550000            11.1573
# 18        14.255556             8.5169
# 19        13.144444             7.6314
# 20        11.550000             7.3899
# 21        11.183333             4.9266
# 22        10.116667             6.6493
# 23        10.200000             3.9284
# 24        10.422222            16.9855
# 25         9.911111            17.2109
# 26        11.183333            10.8192
# 27         7.155556            11.0768
# 28         6.111111             6.6493
# 29         6.788889            13.0088
# 30         7.261111            11.1734
# 31         7.800000            12.8156
# 32         9.872222            13.7494
# 33        12.222222            15.6331
# 34        15.094444            17.5490
# 35        17.355556            22.7815
# 36        19.005556            23.8924
# 37        20.044444            28.3682
# 38        21.050000            26.9031
# 39        21.183333            25.6956
# 40        20.116667            25.3092
# 41        20.216667            18.1125
# 42        20.000000            23.4255
# 43        17.800000            20.0445
# 44        16.061111            21.3969
# 45        15.022222            21.3808
# 46        14.422222            20.0123
# 47        14.255556            16.5025
# 48        13.772222            17.0982
# 49        13.283333            14.3612

# %%
# Out:
# LinearRegression()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x1 = X["Temperature (C)"]
x2 = X["Wind Speed (km/h)"]

ax.scatter(x1, x2, y, c='r', marker='o')

ax.set_xlabel('Temperature(C)')
ax.set_ylabel('Wind Speed(km/h)')
ax.set_zlabel('Humidity')
# Out:
# Text(0.5, 0, 'Humidity')

# %%
from sklearn.linear_model import LinearRegression

mlr_model = LinearRegression()
mlr_model.fit(X, y)
# Out:
# LinearRegression()

# %%
theta0 = mlr_model.intercept_
theta1, theta2= mlr_model.coef_
theta0,theta1,theta2
# Out:
# (1.1431751025645598, -0.03095902199145561, -0.00436079135621688)

# %%
y_pred = mlr_model.predict([[15, 21]])
y_pred
# Out:
# C:\Users\mnank\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([0.58721315])
